# %%
# แก้ไขโค้ดนี้ให้ถูกต้อง

num = int(input("Enter a number: "))
if num < 0:
    text = f"{num} is negative"
elif num > 0:
    text = f"{num} is positive"
else:
    text = f"{num} is zero"

# ตรวจสอบว่าเป็นเลขคู่หรือเลขคี่ และรวมผลลัพธ์ในประโยคเดียว
if num == 0:
    print(f"{text}.")
elif num % 2 == 0:
    print(f"{text} and even number.")
else:
    print(f"{text} and odd number.")
# Out:
# Enter a number: 105
# 105 is positive and odd number.

# %% [markdown]
# **ACTIVITY 2.1**
# การวิเคราะห์ลำดับการทำงานของ Block A: Evaluation Check
# กำหนดให้ค่าเริ่มต้นคือ temp = 25 และ is_raining = True
#
# ขั้นตอนที่ 1 (ตรวจสอบเงื่อนไข if): โปรแกรมจะพิจารณาเงื่อนไข temp > 20 and not is_raining
#
# temp > 20 คือ 25 > 20 ซึ่งเป็น True
#
# not is_raining คือ not True ซึ่งเป็น False
#
# เมื่อเชื่อมด้วย and (True และ False) ผลลัพธ์รวมจึงเป็น False โปรแกรมจึงข้ามไปเช็กเงื่อนไขถัดไป
#
# ขั้นตอนที่ 2 (ตรวจสอบเงื่อนไข elif): โปรแกรมจะพิจารณาเงื่อนไข temp <= 20 or is_raining
#
# temp <= 20 คือ 25 <= 20 ซึ่งเป็น False
#
# is_raining มีค่าเป็น True
#
# เมื่อเชื่อมด้วย or (False หรือ True) ขอแค่มีตัวใดตัวหนึ่งเป็นจริง ผลลัพธ์รวมจึงเป็น True
#
# ขั้นตอนที่ 3 (การแสดงผล): เนื่องจากเงื่อนไขของ elif เป็นจริง โปรแกรมจะเข้ามาทำงานในบล็อกนี้ทันที และข้ามบล็อก else ไป
#
# ผลลัพธ์ (OUTPUT) ของ Block A:
# Stay indoors or bring an umbrella.
#
# การวิเคราะห์ลำดับการทำงานของ Block B: Vectorized Filter
# กำหนดให้ phrase = "Python 2026 Engine"
#
# โปรแกรมใช้ Set Comprehension ในการวนลูปดึงอักขระ c ทีละตัวจากข้อความ phrase
#
# มีการตรวจสอบเงื่อนไข if c.isalpha() and c.lower() not in 'aeiou'
#
# c.isalpha() เพื่อเลือกเฉพาะตัวอักษรภาษาอังกฤษ (ไม่เอาตัวเลข 2026 และช่องว่าง)
#
# c.lower() not in 'aeiou' เพื่อตัดตัวอักษรที่เป็นสระออกไป (เหลือเฉพาะพยัญชนะ)
#
# ผลลัพธ์จะถูกเก็บไว้ในรูปแบบ Set ซึ่งคุณสมบัติของ Set คือจะไม่เก็บข้อมูลที่ซ้ำกัน (ตัวอักษร 'n' ที่ซ้ำกันจะเหลือเพียงตัวเดียว)
#
# ผลลัพธ์ (OUTPUT) ของ Block B:
# Unique consonants: {'p', 'y', 't', 'h', 'n', 'g'} (หมายเหตุ: ลำดับตัวอักษรในวงเล็บปีกกา {} ของแต่ละเครื่องอาจสลับที่กันได้เนื่องจากธรรมชาติของ Set)
